# %%
# %pylab inline
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
Xi_dict = np.load('../FFNN/P_to_Xi/dense_Xi_predictions/Xi_32.npy', allow_pickle=True).item()
Psi_dict = np.load('../POD/P_to_Psi/dense_Psi_predictions/Psi_32.npy', allow_pickle=True).item()

# %%
Psi = Psi_dict['Psi']
Xi = Xi_dict['Xi']

# %%
m = 50000

# %%
figure(figsize = (15,15))
n_rows = 6

for i in range(n_rows):
    for j in range(i+1):
        subplot2grid((n_rows,n_rows),(i,j))
        plot(Psi[m:2*m,i+17],Psi[m:2*m,j+16])
        
#         subplot2grid((3,6),(i,j+3))
#         plot(Xi[:,i+1],Xi[:,j])

# %%
figure(figsize = (15,15))
n_rows = 6

for i in range(n_rows):
    for j in range(i+1):
        subplot2grid((n_rows,n_rows),(i,j))
        plot(Xi[m:2*m,i+17],Xi[m:2*m,j+16])
