# %%
# %pylab inline
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
P = np.load('../Re_17500/pres_hist.npy')
P_time = np.load('../Re_17500/time_hist.npy')

# %%
plot(np.linspace(0,1,51),np.mean(P[:,:51],axis=0), 'r')
plot(np.linspace(0,1,51)[1:-1],np.mean(P[:,51:],axis=0), 'b')

# %%
n_plots = 10
figure(figsize = (15, 3*n_plots))

for j in range(n_plots):
    subplot(n_plots,1,j+1)
    plot(P_time[1000:], P[1000:,10*j], 'b')
#     xlim([90,110])
    axvline(70)
