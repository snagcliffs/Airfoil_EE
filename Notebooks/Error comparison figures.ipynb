# %%
# %pylab inline
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
F_p_error_stats = np.load('./error_statistics/F_p_errors.npy', allow_pickle=True).item()
F_psi_error_stats = np.load('./error_statistics/F_psi_errors.npy', allow_pickle=True).item()
F_xi_error_stats = np.load('./error_statistics/F_xi_errors.npy', allow_pickle=True).item()
H_p_error_stats = np.load('./error_statistics/H_p_errors.npy', allow_pickle=True).item()
H_psi_error_stats = np.load('./error_statistics/H_psi_errors.npy', allow_pickle=True).item()
H_xi_error_stats = np.load('./error_statistics/H_xi_errors.npy', allow_pickle=True).item()

# %%
Taus = F_p_error_stats['Taus']
EE_rates = F_p_error_stats['EE_rates']

F_p_MSE = F_p_error_stats['MSE']
F_p_MAE = F_p_error_stats['MAE']
F_p_alpha_star = F_p_error_stats['alpha_star']
F_p_Qi_KL = F_p_error_stats['Qi_KL']
F_p_F1_opt = F_p_error_stats['F1_opt']
F_p_Q_opt = F_p_error_stats['Q_opt']
F_p_F1 = F_p_error_stats['F1']
F_p_AUC = F_p_error_stats['AUC']

F_psi_MSE = F_psi_error_stats['MSE']
F_psi_MAE = F_psi_error_stats['MAE']
F_psi_alpha_star = F_psi_error_stats['alpha_star']
F_psi_Qi_KL = F_psi_error_stats['Qi_KL']
F_psi_F1_opt = F_psi_error_stats['F1_opt']
F_psi_Q_opt = F_psi_error_stats['Q_opt']
F_psi_F1 = F_psi_error_stats['F1']
F_psi_AUC = F_psi_error_stats['AUC']

F_xi_MSE = F_xi_error_stats['MSE']
F_xi_MAE = F_xi_error_stats['MAE']
F_xi_alpha_star = F_xi_error_stats['alpha_star']
F_xi_Qi_KL = F_xi_error_stats['Qi_KL']
F_xi_F1_opt = F_xi_error_stats['F1_opt']
F_xi_Q_opt = F_xi_error_stats['Q_opt']
F_xi_F1 = F_xi_error_stats['F1']
F_xi_AUC = F_xi_error_stats['AUC']

H_psi_MSE = H_psi_error_stats['MSE']
H_psi_MAE = H_psi_error_stats['MAE']
H_psi_alpha_star = H_psi_error_stats['alpha_star']
H_psi_Qi_KL = H_psi_error_stats['Qi_KL']
H_psi_F1_opt = H_psi_error_stats['F1_opt']
H_psi_Q_opt = H_psi_error_stats['Q_opt']
H_psi_F1 = H_psi_error_stats['F1']
H_psi_AUC = H_psi_error_stats['AUC']

H_p_MSE = H_p_error_stats['MSE']
H_p_MAE = H_p_error_stats['MAE']
H_p_alpha_star = H_p_error_stats['alpha_star']
H_p_Qi_KL = H_p_error_stats['Qi_KL']
H_p_F1_opt = H_p_error_stats['F1_opt']
H_p_Q_opt = H_p_error_stats['Q_opt']
H_p_F1 = H_p_error_stats['F1']
H_p_AUC = H_p_error_stats['AUC']

H_xi_MSE = H_xi_error_stats['MSE']
H_xi_MAE = H_xi_error_stats['MAE']
H_xi_alpha_star = H_xi_error_stats['alpha_star']
H_xi_Qi_KL = H_xi_error_stats['Qi_KL']
H_xi_F1_opt = H_xi_error_stats['F1_opt']
H_xi_Q_opt = H_xi_error_stats['Q_opt']
H_xi_F1 = H_xi_error_stats['F1']
H_xi_AUC = H_xi_error_stats['AUC']

# %%
figure(figsize = (15,4))
label_fs = 18

subplot(1,3,1)
plot(Taus, F_p_MSE, 'k', label=r'$F_p$')
plot(Taus, F_psi_MSE, 'b', label=r'$F_\psi$')
plot(Taus, F_xi_MSE, 'r', label=r'$F_\xi$')
plot(Taus, H_p_MSE, 'k--', label=r'$H_p$')
plot(Taus, H_psi_MSE, 'b--', label=r'$H_\psi$')
plot(Taus, H_xi_MSE, 'r--', label=r'$H_\xi$')
xticks(fontsize = label_fs)
yticks(fontsize = label_fs)
xlabel(r'$\tau$', fontsize = label_fs)
ylabel(r'MSE', fontsize = label_fs)
xlim([Taus[0], Taus[-1]])

subplot(1,3,2)
plot(Taus, F_p_alpha_star, 'k')
plot(Taus, F_psi_alpha_star, 'b')
plot(Taus, F_xi_alpha_star, 'r')
plot(Taus, H_p_alpha_star, 'k--')
plot(Taus, H_psi_alpha_star, 'b--')
plot(Taus, H_xi_alpha_star, 'r--')
xticks(fontsize = label_fs)
yticks(fontsize = label_fs)
xlabel(r'$\tau$', fontsize = label_fs)
ylabel(r'$\alpha^*$', fontsize = label_fs)
xlim([Taus[0], Taus[-1]])

subplot(1,3,3)
plot(Taus, F_p_Qi_KL, 'k', label=r'$F_p$')
plot(Taus, H_p_Qi_KL, 'k--', label=r'$H_p$')
plot(Taus, F_psi_Qi_KL, 'b', label=r'$F_\psi$')
plot(Taus, H_psi_Qi_KL, 'b--', label=r'$H_\psi$')
plot(Taus, F_xi_Qi_KL, 'r', label=r'$F_\xi$')
plot(Taus, H_xi_Qi_KL, 'r--', label=r'$H_\xi$')
xticks(fontsize = label_fs)
yticks(fontsize = label_fs)
xlabel(r'$\tau$', fontsize = label_fs)
ylabel(r'BRE', fontsize = label_fs)
xlim([Taus[0], Taus[-1]])
legend(loc = 'upper left', ncol=3, fontsize = label_fs, 
       handletextpad=0.1, handlelength=1, columnspacing=1)

tight_layout()

# %%
figure(figsize = (15,3))
label_fs = 18

subplot(1,3,1)
plot(Taus, F_p_MSE, 'k', label=r'$F_p$')
plot(Taus, F_psi_MSE, 'b', label=r'$F_\psi$')
plot(Taus, F_xi_MSE, 'r', label=r'$F_\xi$')
plot(Taus, H_p_MSE, 'k--', label=r'$H_p$')
plot(Taus, H_psi_MSE, 'b--', label=r'$H_\psi$')
plot(Taus, H_xi_MSE, 'r--', label=r'$H_\xi$')
xticks(fontsize = label_fs)
yticks(fontsize = label_fs)
xlabel(r'$\tau$', fontsize = label_fs)
ylabel(r'MSE', fontsize = label_fs)
xlim([Taus[0], Taus[-1]])

subplot(1,3,2)
plot(Taus, F_p_alpha_star, 'k')
plot(Taus, F_psi_alpha_star, 'b')
plot(Taus, F_xi_alpha_star, 'r')
plot(Taus, H_p_alpha_star, 'k--')
plot(Taus, H_psi_alpha_star, 'b--')
plot(Taus, H_xi_alpha_star, 'r--')
xticks(fontsize = label_fs)
yticks(fontsize = label_fs)
xlabel(r'$\tau$', fontsize = label_fs)
ylabel(r'$\alpha^*$', fontsize = label_fs)
xlim([Taus[0], Taus[-1]])

subplot(1,3,3)
plot(Taus, F_p_Qi_KL, 'k', label=r'$F_p$')
plot(Taus, H_p_Qi_KL, 'k--', label=r'$H_p$')
plot(Taus, F_psi_Qi_KL, 'b', label=r'$F_\psi$')
plot(Taus, H_psi_Qi_KL, 'b--', label=r'$H_\psi$')
plot(Taus, F_xi_Qi_KL, 'r', label=r'$F_\xi$')
plot(Taus, H_xi_Qi_KL, 'r--', label=r'$H_\xi$')
xticks(fontsize = label_fs)
yticks(fontsize = label_fs)
xlabel(r'$\tau$', fontsize = label_fs)
ylabel(r'BRE', fontsize = label_fs)
xlim([Taus[0], Taus[-1]])
legend(loc = 'upper left', ncol=3, fontsize = label_fs-2, 
       handletextpad=0.1, handlelength=1, columnspacing=1)

tight_layout()

# %%
fig = figure(figsize = (15,6))
label_fs = 18

Titles = [r'$F_p$', r'$F_\psi$', r'$F_\xi$', r'$H_p$', r'$H_\psi$', r'$H_\xi$']
subfig_width = 5
cbar_width = 2
fig_width = 6*subfig_width + cbar_width

subplot2grid((2,fig_width),(0,0),rowspan=1, colspan=subfig_width)
pcolor(Taus, EE_rates, F_p_F1, shading='auto', vmin=0, vmax=1)
xticks(fontsize=0)
yticks(fontsize=label_fs)
title(Titles[0], fontsize=label_fs)
ylabel(r'$F_{1,opt}(\omega,\tau)$', fontsize=label_fs)

subplot2grid((2,fig_width),(0,subfig_width),rowspan=1, colspan=5)
pcolor(Taus, EE_rates, F_psi_F1, shading='auto', vmin=0, vmax=1)
xticks(fontsize=0)
yticks(fontsize=0)
title(Titles[1], fontsize=label_fs)

subplot2grid((2,fig_width),(0,2*subfig_width),rowspan=1, colspan=subfig_width)
pcolor(Taus, EE_rates, F_xi_F1, shading='auto', vmin=0, vmax=1)
xticks(fontsize=0)
yticks(fontsize=0)
title(Titles[2], fontsize=label_fs)

subplot2grid((2,fig_width),(0,3*subfig_width),rowspan=1, colspan=subfig_width)
pcolor(Taus, EE_rates, H_p_F1, shading='auto', vmin=0, vmax=1)
xticks(fontsize=0)
yticks(fontsize=0)
title(Titles[3], fontsize=label_fs)

subplot2grid((2,fig_width),(0,4*subfig_width),rowspan=1, colspan=subfig_width)
pcolor(Taus, EE_rates, H_psi_F1, shading='auto', vmin=0, vmax=1)
xticks(fontsize=0)
yticks(fontsize=0)
title(Titles[4], fontsize=label_fs)

subplot2grid((2,fig_width),(0,5*subfig_width),rowspan=1, colspan=subfig_width)
pcolor(Taus, EE_rates, H_xi_F1, shading='auto', vmin=0, vmax=1)
xticks(fontsize=0)
yticks(fontsize=0)
title(Titles[5], fontsize=label_fs)

subplot2grid((2,fig_width),(1,0),rowspan=1, colspan=subfig_width)
pcolor(Taus, EE_rates, F_p_AUC, shading='auto', vmin=0, vmax=1)
xticks(fontsize=label_fs)
yticks(fontsize=label_fs)
xlabel(r'$\tau$', fontsize=label_fs)
ylabel(r'$\alpha^*(\omega,\tau)$', fontsize=label_fs)

subplot2grid((2,fig_width),(1,subfig_width),rowspan=1, colspan=subfig_width)
pcolor(Taus, EE_rates, F_psi_AUC, shading='auto', vmin=0, vmax=1)
xticks(fontsize=label_fs)
yticks(fontsize=0)
xlabel(r'$\tau$', fontsize=label_fs)

subplot2grid((2,fig_width),(1,2*subfig_width),rowspan=1, colspan=subfig_width)
pcolor(Taus, EE_rates, F_xi_AUC, shading='auto', vmin=0, vmax=1)
xticks(fontsize=label_fs)
yticks(fontsize=0)
xlabel(r'$\tau$', fontsize=label_fs)

subplot2grid((2,fig_width),(1,3*subfig_width),rowspan=1, colspan=subfig_width)
pcolor(Taus, EE_rates, H_p_AUC, shading='auto', vmin=0, vmax=1)
xticks(fontsize=label_fs)
yticks(fontsize=0)
xlabel(r'$\tau$', fontsize=label_fs)

subplot2grid((2,fig_width),(1,4*subfig_width),rowspan=1, colspan=subfig_width)
pcolor(Taus, EE_rates, H_psi_AUC, shading='auto', vmin=0, vmax=1)
xticks(fontsize=label_fs)
yticks(fontsize=0)
xlabel(r'$\tau$', fontsize=label_fs)

subplot2grid((2,fig_width),(1,5*subfig_width),rowspan=1, colspan=subfig_width)
im = pcolor(Taus, EE_rates, H_xi_AUC, shading='auto', vmin=0, vmax=1)
xticks(fontsize=label_fs)
yticks(fontsize=0)
xlabel(r'$\tau$', fontsize=label_fs)

fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.94, 0.132, 0.01, 0.8])
cbar = fig.colorbar(im, cax=cbar_ax)
cbar.ax.tick_params(labelsize=label_fs)

tight_layout()

# fig.savefig('test.svg')
# Out:
# <ipython-input-6-2bc22e4c50e7>:88: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   tight_layout()

# %%
fig = figure(figsize = (15,7.5))
label_fs = 18

fig_width = 4
cbar_width = 1
col_width = 4

AUC_all = [F_p_AUC, F_psi_AUC, F_xi_AUC, H_p_AUC, H_psi_AUC, H_xi_AUC]
F1_all = [F_p_F1, F_psi_F1, F_xi_F1, H_p_F1, H_psi_F1, H_xi_F1]
Titles = [r'$F_p$', r'$F_\psi$', r'$F_\xi$', r'$H_p$', r'$H_\psi$', r'$H_\xi$']

vmax = 0
for i in range(1,5):
    for j in range(i):
        vals_1 = F1_all[i-1]
        vals_2 = F1_all[(j+4)%5]
        vmax = np.max([vmax,np.max(np.abs(vals_1 - vals_2))])

for i in range(1,6):
    for j in range(i):

        subplot2grid((5*fig_width,10*fig_width+col_width), 
                     ((i-1)*fig_width,j*fig_width), 
                     rowspan=fig_width, colspan=fig_width)
        
        vals_1 = AUC_all[i-1]
        vals_2 = AUC_all[(j+5)%6]
        
        im = pcolor(Taus, EE_rates, vals_1-vals_2, shading='auto', vmin=-vmax, vmax=vmax, cmap='bwr')
        
        if i == 5:
            xticks([0,4,8], fontsize=label_fs-2)
                
            xlabel(Titles[(j+5)%6], fontsize=label_fs)
        else:
            xticks([],fontsize=0)
        
        if j == 0:
            yticks(fontsize=label_fs-2)
            ylabel(Titles[i-1], fontsize=label_fs)
        else:
            yticks([],fontsize=0)

cax2 = fig.add_axes([0.1975, 0.735, 0.0075, 0.145]) #Add position (left, bottom, width, height)
cbar = fig.colorbar(im, cax=cax2)
cbar.ax.tick_params(labelsize=label_fs-2)
            
for i in range(1,6):
    for j in range(i):

        subplot2grid((5*fig_width,10*fig_width), 
                     ((i-1)*fig_width,(j+5)*fig_width), 
                     rowspan=fig_width, colspan=fig_width)
        
        vals_1 = F1_all[i-1]
        vals_2 = F1_all[(j+5)%6]
        
        im = pcolor(Taus, EE_rates, vals_1-vals_2, shading='auto', vmin=-vmax, vmax=vmax, cmap='bwr')
        
        if i == 5:
            xticks([0,4,8], fontsize=label_fs-2)
            xlabel(Titles[(j+5)%6], fontsize=label_fs)
        else:
            xticks([],fontsize=0)
        
        if j == 0:
            yticks(fontsize=label_fs-2)
#             ylabel(Titles[i-1], fontsize=label_fs)
        else:
            yticks([],fontsize=0)
            
# cax = subplot2grid((4*fig_width,8*fig_width), (0,5*fig_width), rowspan=fig_width, colspan=cbar_width)
# cax2 = inset_axes(cax,
#                   width="20%",  # width = 50% of parent_bbox width
#                   height="100%",  # height : 5%
#                 loc='center left')

cax2 = fig.add_axes([0.5925, 0.735, 0.0075, 0.145])
cbar = fig.colorbar(im, cax=cax2)
cbar.ax.tick_params(labelsize=label_fs-2)
yticks([])
        
tight_layout()
# fig.savefig('test.pdf')
# Out:
# <ipython-input-7-367efe4ba0fe>:81: UserWarning: Use the colorbar set_ticks() method instead.
#   yticks([])
# <ipython-input-7-367efe4ba0fe>:83: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   tight_layout()
# <ipython-input-7-367efe4ba0fe>:83: UserWarning: tight_layout not applied: number of columns in subplot specifications must be multiples of one another.
#   tight_layout()
