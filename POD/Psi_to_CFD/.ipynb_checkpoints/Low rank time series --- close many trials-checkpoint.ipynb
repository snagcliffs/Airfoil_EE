# %%
# %pylab inline
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
results = np.load('./close_POD_trials/results.npy', allow_pickle=True).item()

# %%
Cd_true = results['Cd_true']
Cl_true = results['Cl_true']
Cd_25 = results['Cd_25']
Cl_25 = results['Cl_25']
Cd_50 = results['Cd_50']
Cl_50 = results['Cl_50']
Cd_100 = results['Cd_100']
Cl_100 = results['Cl_100']

tau = results['tau']
dt = results['dt']
t = np.linspace(dt,tau,int(tau/dt))
n_samp = len(Cd_true)

# %%
sample_nums = np.arange(1,3) # first one is off since I forgot to delete a file

figure(figsize = (15,4*len(sample_nums)))
label_fs = 16

for j in range(len(sample_nums)):
    
    sample_num = sample_nums[j]
    
    subplot(len(sample_nums),2,2*j+1)
    plot(t,Cd_true[sample_num][1:], 'b', label='True')
    plot(t,Cd_25[sample_num][1:], 'r--', label='r=25')
    plot(t,Cd_50[sample_num][1:], 'g--', label='r=25')
    plot(t,Cd_100[sample_num][1:], 'k--', label='r=100')
    xlim(t[0],t[-1])
    
    yticks(fontsize = label_fs)
    ylabel(r'Sample '+str(sample_num), fontsize = label_fs)
    
    if j == 0: 
        title(r'$C_d$', fontsize = label_fs+2)
        legend(loc = 'upper left', ncol=3, fontsize = label_fs)
    elif j == len(sample_nums)-1:
        xticks(fontsize = label_fs)
        xlabel('Time', fontsize = label_fs)
    else:
        xticks([])

    subplot(len(sample_nums),2,2*j+2)
    plot(t,Cl_true[sample_num][1:], 'b', label='True')
    plot(t,Cl_25[sample_num][1:], 'r--', label='r=25')
    plot(t,Cl_50[sample_num][1:], 'g--', label='r=25')
    plot(t,Cl_100[sample_num][1:], 'k--', label='r=100')
    xlim(t[0],t[-1])
    
    yticks(fontsize = label_fs)    
    if j == 0: 
        title(r'$C_l$', fontsize = label_fs+2)
    elif j == len(sample_nums)-1:
        xticks(fontsize = label_fs)
        xlabel('Time', fontsize = label_fs)
    else:
        xticks([])
    
tight_layout()

# %%
Cd_err_full = np.mean([np.abs(Cd_true[j][1:] - Cd_full[j][1:])/np.std(Cd_true[j][1:]) for j in range(n_samp)], axis=0)
Cd_err_10 = np.mean([np.abs(Cd_true[j][1:] - Cd_10[j][1:])/np.std(Cd_true[j][1:]) for j in range(n_samp)], axis=0)
Cd_err_100 = np.mean([np.abs(Cd_true[j][1:] - Cd_100[j][1:])/np.std(Cd_true[j][1:]) for j in range(n_samp)], axis=0)

Cl_err_full = np.mean([np.abs(Cl_true[j][1:] - Cl_full[j][1:])/np.std(Cl_true[j][1:]) for j in range(n_samp)], axis=0)
Cl_err_10 = np.mean([np.abs(Cl_true[j][1:] - Cl_10[j][1:])/np.std(Cl_true[j][1:]) for j in range(n_samp)], axis=0)
Cl_err_100 = np.mean([np.abs(Cl_true[j][1:] - Cl_100[j][1:])/np.std(Cl_true[j][1:]) for j in range(n_samp)], axis=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-e23a019219a6> in <module>
# ----> 1 Cd_err_full = np.mean([np.abs(Cd_true[j][1:] - Cd_full[j][1:])/np.std(Cd_true[j][1:]) for j in range(n_samp)], axis=0)
#       2 Cd_err_10 = np.mean([np.abs(Cd_true[j][1:] - Cd_10[j][1:])/np.std(Cd_true[j][1:]) for j in range(n_samp)], axis=0)
#       3 Cd_err_100 = np.mean([np.abs(Cd_true[j][1:] - Cd_100[j][1:])/np.std(Cd_true[j][1:]) for j in range(n_samp)], axis=0)
#       4
#       5 Cl_err_full = np.mean([np.abs(Cl_true[j][1:] - Cl_full[j][1:])/np.std(Cl_true[j][1:]) for j in range(n_samp)], axis=0)
#
# <ipython-input-12-e23a019219a6> in <listcomp>(.0)
# ----> 1 Cd_err_full = np.mean([np.abs(Cd_true[j][1:] - Cd_full[j][1:])/np.std(Cd_true[j][1:]) for j in range(n_samp)], axis=0)
# ...
